# %%
import pandas as pd
import pickle

# %%
df1 = pd.read_csv("/media/rajlab/sachin_data_2/userdata/akanksha/ADNI_BIDS/conversion_info/t1_paths.tsv", sep="\t")

# %%
df1
# Out:
#       Field_Strength  Image_ID  Original   Scan_Date  \
# 0                1.5      8793      True  2005-11-15
# 1                1.5     16637      True  2006-06-02
# 2                1.5     30818      True  2006-11-28
# 3                1.5     55088      True  2007-05-22
# 4                1.5     82890      True  2007-11-15
# ...              ...       ...       ...         ...
# 6401             3.0   1047860      True  2018-09-11
# 6402             3.0   1028011      True  2018-07-27
# 6403             3.0   1080321      True  2018-11-21
# 6404             3.0   1130589      True  2019-02-14
# 6405             3.0   1131613      True  2019-02-14
#
#                             Sequence  Series_ID  Study_ID  Subject_ID VISCODE  \
# 0                 ADNI_STUDY_MPRAGE1      10145      2674  100_S_0006      bl
# 1                  ADNI-R11___MPRAGE      15294      4099  100_S_0006     m06
# 2                  ADNI-R11___MPRAGE      23093      6082  100_S_0006     m12
# ...
